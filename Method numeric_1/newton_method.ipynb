# %%
# Populates the notebook with the most used numerical packages
# %pylab notebook
# Import numpy for array processing
import numpy as np
# Import pyplot for graphics
import matplotlib.pyplot as plt
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# No método de Newton, considero a função 𝑓(𝑥)=𝑙𝑛(𝑥)−1
# que possui raiz Xts = 𝑒, eu considero que X1 = 2.7 e calculos 3 iterações utilizando o método de Newton, Tolerância do valor de 10−9

# %%
# %matplotlib notebook
#Creating the function f(x) = ln(x)-1
def f(x):
    return np.log(x)-1

x = np.arange(-5, 20, 0.01)
y = f(x)

# Display on screen the function
plt.figure()
plt.plot(x, y, 'r-.')
plt.xlabel('$x$')
plt.ylabel('$p(x) = log(x)-1 $')
plt.grid(True)
plt.show()
# Out:
# <ipython-input-17-4524418ce32a>:4: RuntimeWarning: invalid value encountered in log
#   return np.log(x)-1
# <img src="data:image/png;base64,..." width="572.85">

# %%
# %matplotlib notebook
#Creating the fuction f(x)
def f(x):
    return np.log(x)-1
# Creating the derivative of function f(x)
def df(x):
    return 1/x

#Creating the method of newton
def Newton(f, df, x0 ,tol=1e-9, disp =False): # Input values
    iterNum =1; #Iniciating one unit of counter
    while True: #This loop going to happen until break the condition abs(x-x0) < tol
        x= x0 - f(x0)/df(x0)  # The method
        
        if disp: #Display on screen the Table of each iteractions
            print("Iter: %3d | x: %+.7e | f(x): %+.7e | f'(x): %+.7e| x: %+.7e" \
                  %(iterNum, x0, f(x0), df(x0), x))
        if abs(x-x0) < tol:
            break; #Break the code if the tolerance is achieve
        x0=x;
        iterNum +=1 # Increase one unit of counter number interactions
    return x

Xns = Newton(f, df, 2.7, disp= True)

#Plotting the graphic of f(x) for x in [2:3,4] and plotting the value of Xns as well.
x = np.arange( 2, 3.4 ,0.1)
y = f(x)
plt.figure()
plt.plot(x, y, 'r-.', label = '$f(x)$') 
plt.plot(Xns, f(Xns), 'bo', label = '$X_{NS}$')
plt.grid()
plt.ylabel('$f(x)= log(x)-1 $')
plt.xlabel('$x$')
plt.legend()
plt.show()
# Out:
# Iter:   1 | x: +2.7000000e+00 | f(x): -6.7482270e-03 | f'(x): +3.7037037e-01| x: +2.7182202e+00
# Iter:   2 | x: +2.7182202e+00 | f(x): -2.2667365e-05 | f'(x): +3.6788778e-01| x: +2.7182818e+00
# Iter:   3 | x: +2.7182818e+00 | f(x): -2.5690094e-10 | f'(x): +3.6787944e-01| x: +2.7182818e+00
# <img src="data:image/png;base64,..." width="572.85">
