# %%
# Populates the notebook with the most used numerical packages
# %pylab notebook
# Import numpy for array processing
import numpy as np
# Import pyplot for graphics
import matplotlib.pyplot as plt
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
#  Usando o número de iteraçoes igual a 10, um intervalo[𝑎,𝑏]
# de [−0.9,1.9] a respeito da função 𝑓(𝑥)=𝑥2−𝑥−2

# %%
# Organize the coefficients of the polynomial
p = np.array([1, -1, -2], dtype=float)

# Determine the roots of the polynomial
r = np.roots(p)
print('Roots: ', r)

# Plot the function graph and mark the roots
x = np.arange(-20, 10, 0.001)
y = np.polyval(p, x)
x0 = r
y0 = np.polyval(p, r)

# Display on screen 
plt.figure()
plt.plot(x, y, 'b-')
plt.plot(x0, y0, 'ro')
plt.xlabel('$x$')
plt.ylabel('$p(x) = x^2 -x-2.0$')
plt.grid(True)
plt.show()
# Out:
# Roots:  [ 2. -1.]
# <img src="data:image/png;base64,..." width="572.85">

# %%
import math 
# Creating the function F(X)
def F(x):
    p = np.array([1, -1, -2], dtype=float)

    return np.polyval(p, x)

# Creating the Falseposition method
def falseposition(F, a, b, numIter, tol = 1e-3):
    #numIter is the counter number of iteractions
    #tol is the tolerance
    x0 = np.empty(shape=numIter) #The points of acurrate the function 
    y0 = np.empty(shape=numIter) #The points of acurrate the function
    
    fa , fb,  = F(a) , F(b), # Atribuition each values in each function
    
    #Verify if is a available value 
    if fa*fb >=0:
        print("Error ")
        return None #stop the program
    
    for i in range(0, numIter): #The method is going to be apply the number of iteractins stabilish 
        x = (a*fb)-(b*fa)/(fb-fa) # the method
        fx  = F(x) # Atribuition the values in the function
        x0[i] = x # Update the points
        y0[i] = fx #Update the points
        #Verify which one of interval extremes must be update
        if fa*fx < 0:
            #Update the extreme b and f(b)
            b = x
            fb = fx
        if fb*fx < 0:
            #Update the extreme a and f(a)
            a = x
            fa = fx
        if abs(fx) <=tol : #Considering of tolerance on the function value
            print("the precision is accurate ")
            break ;
        
    return (x0, y0)

# %%
# Apply the false position method
a, b = -0.9 ,2.1 # Stabilish the input values
numIter = 10  # Stabilish the number of iteractions
x0, y0 = falseposition(F, a, b, numIter ) #Call it the falseposition function
# Show the results
x = np.arange(a, b, np.abs(b-a)/100)
y = F(x)

# Display on screen the method apply
plt.figure()
plt.plot(x, y, 'b-')
plt.plot(x0, y0, 'ro')
plt.xlabel('$x$')
plt.ylabel('$p(x)$')
plt.grid(True)
for i in range(0, numIter):
    plt.text(x0[i], y0[i], i)
plt.show()

for i in range(0, numIter):
    print('Iteration: ', i, ' Approx. root: ', x0[i])
# Out:
# the precision is accurate
# <img src="data:image/png;base64,..." width="572.85">
# Iteration:  0  Approx. root:  0.7359999999999988
# Iteration:  1  Approx. root:  2.068207534165181
# Iteration:  2  Approx. root:  2.0421590890051524
# Iteration:  3  Approx. root:  2.0237838821334853
# Iteration:  4  Approx. root:  2.0124913319866637
# Iteration:  5  Approx. root:  2.0062567709154795
# Iteration:  6  Approx. root:  2.003049167994841
# Iteration:  7  Approx. root:  2.0014646120747828
# Iteration:  8  Approx. root:  2.0006984164860464
# Iteration:  9  Approx. root:  2.000331874049852
